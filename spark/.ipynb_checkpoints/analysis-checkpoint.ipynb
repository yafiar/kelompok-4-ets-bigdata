# %%
# !pip install pyspark pandas
# Out:
# Collecting pyspark
#   Using cached pyspark-4.1.1-py2.py3-none-any.whl
# Requirement already satisfied: pandas in c:\users\kimchoon\anaconda3\lib\site-packages (2.2.2)
# Collecting py4j<0.10.9.10,>=0.10.9.7 (from pyspark)
#   Using cached py4j-0.10.9.9-py2.py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\kimchoon\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\kimchoon\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kimchoon\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\kimchoon\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\kimchoon\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Using cached py4j-0.10.9.9-py2.py3-none-any.whl (203 kB)
# Installing collected packages: py4j, pyspark
# Successfully installed py4j-0.10.9.9 pyspark-4.1.1

# %%
import os
import sys

# Path 100% bebas spasi!
java_path = r"C:\java11"

os.environ["JAVA_HOME"] = java_path
os.environ["PATH"] = java_path + r"\bin;" + os.environ["PATH"]

print("JAVA_HOME berhasil diset ke:", os.environ["JAVA_HOME"])
# Out:
# JAVA_HOME berhasil diset ke: C:\java11

# %% [markdown]
# # Import Library dan Setup Spark

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, max as spark_max, min as spark_min, avg, window, to_timestamp, lower, when, lag, date_format, lit
from pyspark.sql.window import Window

# Inisialisasi Spark Session
spark = SparkSession.builder \
    .appName("Analisis_Harga_Pangan_Kelompok4") \
    .getOrCreate()

print("Spark Session Berhasil Dibuat!")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 8
#       3 from pyspark.sql.window import Window
#       5 # Inisialisasi Spark Session
#       6 spark = SparkSession.builder \
#       7     .appName("Analisis_Harga_Pangan_Kelompok4") \
# ----> 8     .getOrCreate()
#      10 print("Spark Session Berhasil Dibuat!")
#
# File c:\Users\kimchoon\anaconda3\Lib\site-packages\pyspark\sql\session.py:560, in SparkSession.Builder.getOrCreate(self)
#     557     sc = SparkContext.getOrCreate(sparkConf)
#     558     # Do not update `SparkConf` for existing `SparkContext`, as it's shared
#     559     # by all sessions.
# --> 560     session = SparkSession(sc, options=self._options)
#     561 else:
#     562     module = SparkSession._get_j_spark_session_module(session._jvm)
#
# File c:\Users\kimchoon\anaconda3\Lib\site-packages\pyspark\sql\session.py:636, in SparkSession.__init__(self, sparkContext, jsparkSession, options)
#     632 jSparkSessionModule = SparkSession._get_j_spark_session_module(self._jvm)
#     634 if jsparkSession is None:
#     635     if (
# --> 636         jSparkSessionClass.getDefaultSession().isDefined()
#     637         and not jSparkSessionClass.getDefaultSession().get().sparkContext().isStopped()
#     638     ):
#     639         jsparkSession = jSparkSessionClass.getDefaultSession().get()
#     640         jSparkSessionModule.applyModifiableSettings(jsparkSession, options)
#
# TypeError: 'JavaPackage' object is not callable

# %% [markdown]
# # Load Data dari HDFS

# %%
# Sesuaikan URL HDFS dengan setup Docker Anggota 1 (Infrastruktur)
HDFS_API_PATH = "hdfs://localhost:9000/data/pangan/api/*"
HDFS_RSS_PATH = "hdfs://localhost:9000/data/pangan/rss/*"

try:
    # Load Data Harga Pangan
    df_api = spark.read.json(HDFS_API_PATH)
    # Konversi string timestamp ISO ke timestamp Spark
    df_api = df_api.withColumn("timestamp", to_timestamp(col("timestamp"), "yyyy-MM-dd'T'HH:mm:ss"))
    
    print("Skema Data Harga (API):")
    df_api.printSchema()
except Exception as e:
    print("Data API belum tersedia di HDFS:", e)

try:
    # Load Data Berita RSS
    df_rss = spark.read.json(HDFS_RSS_PATH)
    # Asumsi kolom RSS dari Anggota 3: title, link, published/timestamp
    if "timestamp" in df_rss.columns:
        df_rss = df_rss.withColumn("timestamp", to_timestamp(col("timestamp")))
    elif "published" in df_rss.columns:
        df_rss = df_rss.withColumn("timestamp", to_timestamp(col("published")))
        
    print("Skema Data RSS:")
    df_rss.printSchema()
except Exception as e:
    print("Data RSS belum tersedia di HDFS:", e)

# %% [markdown]
# # Analisisis  Votalitas Harga

# %%
# Menghitung volatilitas: (max - min) / avg * 100
df_volatilitas = df_api.groupBy("komoditas").agg(
    spark_max("harga").alias("harga_max"),
    spark_min("harga").alias("harga_min"),
    avg("harga").alias("harga_avg")
)

df_volatilitas = df_volatilitas.withColumn(
    "volatilitas_persen",
    ((col("harga_max") - col("harga_min")) / col("harga_avg")) * 100
).orderBy(col("volatilitas_persen").desc())

print("=== Ranking Komoditas Paling Fluktuatif ===")
df_volatilitas.show()

# %% [markdown]
# # Analisis Tren Harga

# %%
# Grouping berdasarkan Komoditas dan Waktu (Per jam)
df_api_waktu = df_api.withColumn("waktu_jam", date_format(col("timestamp"), "yyyy-MM-dd HH:00:00"))

df_tren = df_api_waktu.groupBy("komoditas", "waktu_jam").agg(
    avg("harga").alias("harga_rata_rata")
)

# Window Function untuk melihat pergerakan naik/turun
windowSpec = Window.partitionBy("komoditas").orderBy("waktu_jam")
df_tren = df_tren.withColumn("harga_sebelumnya", lag("harga_rata_rata", 1).over(windowSpec))

# Logic Naik/Turun
df_tren = df_tren.withColumn(
    "status_tren",
    when(col("harga_sebelumnya").isNull(), "Awal")
    .when(col("harga_rata_rata") > col("harga_sebelumnya"), "Naik")
    .when(col("harga_rata_rata") < col("harga_sebelumnya"), "Turun")
    .otherwise("Stabil")
)

print("=== Tren Harga Komoditas ===")
df_tren.orderBy("waktu_jam", "komoditas").show()

# %% [markdown]
# # Analisis Koerelasi Berita

# %%
# Daftar kata kunci komoditas yang akan dicari di judul berita
list_komoditas = ["beras", "cabai", "bawang", "daging", "telur", "ayam"]

# Samakan format waktu di data RSS
df_rss_waktu = df_rss.withColumn("waktu_jam", date_format(col("timestamp"), "yyyy-MM-dd HH:00:00"))
df_rss_lower = df_rss_waktu.withColumn("judul_lower", lower(col("title"))) # Asumsi kolomnya 'title'

korelasi_df = None
for k in list_komoditas:
    # Filter berita yang mengandung kata kunci komoditas di judulnya
    df_k = df_rss_lower.filter(col("judul_lower").contains(k)) \
                       .groupBy("waktu_jam") \
                       .count() \
                       .withColumnRenamed("count", "jumlah_berita") \
                       .withColumn("komoditas", lit(k))
    
    if korelasi_df is None:
        korelasi_df = df_k
    else:
        korelasi_df = korelasi_df.union(df_k)

# Gabungkan Data Tren Harga dan Data Berita berdasarkan Komoditas & Waktu
if korelasi_df is not None:
    df_korelasi_akhir = df_tren.join(korelasi_df, on=["komoditas", "waktu_jam"], how="left").fillna(0)
    print("=== Korelasi Tren Harga & Eksposur Berita ===")
    df_korelasi_akhir.orderBy("waktu_jam", "komoditas").show()
else:
    # Fallback jika data RSS kosong
    df_korelasi_akhir = df_tren.withColumn("jumlah_berita", lit(0))

# %% [markdown]
# # Output Data dan Export untuk Dashboard

# %%
# 1. Simpan ke HDFS (/data/pangan/hasil/)
HDFS_HASIL_PATH = "hdfs://localhost:9000/data/pangan/hasil/"

# Kita menyimpannya dalam format JSON
df_volatilitas.write.mode("overwrite").json(HDFS_HASIL_PATH + "volatilitas")
df_tren.write.mode("overwrite").json(HDFS_HASIL_PATH + "tren")
df_korelasi_akhir.write.mode("overwrite").json(HDFS_HASIL_PATH + "korelasi")

print("Berhasil disimpan ke HDFS!")

# ====================================================================
# 2. EXPORT KE LOKAL UNTUK DASHBOARD (Bentuk Array JSON Tunggal)
# ====================================================================
# Karena Spark memecah JSON per partisi, kita convert ke Pandas dulu 
# untuk dijadikan 1 file JSON bersih yang mudah dibaca frontend.

# Sesuaikan relatif path ke folder anggota 5
PATH_DASHBOARD = "../dashboard/data"
os.makedirs(PATH_DASHBOARD, exist_ok=True)

hasil_export = {
    "volatilitas": df_volatilitas.toPandas().to_dict(orient="records"),
    "tren_harga": df_tren.toPandas().to_dict(orient="records"),
    "korelasi_berita": df_korelasi_akhir.toPandas().to_dict(orient="records")
}

with open(f"{PATH_DASHBOARD}/spark_results.json", "w") as f:
    json.dump(hasil_export, f, indent=4)

print(f"File berhasil diexport untuk Anggota 5 di: {PATH_DASHBOARD}/spark_results.json")
